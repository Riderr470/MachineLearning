# %%
import tensorflow as tf
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
cpus = tf.config.experimental.list_physical_devices('CPU')
tf.config.threading.set_intra_op_parallelism_threads(2)
tf.config.threading.set_inter_op_parallelism_threads(2)
#with tf.device('/CPU:0'):

# %% [markdown]
# # remove dodgy images

# %%
import cv2
import imghdr

# %%
data_dir = 'data'
img_exts = ['jpeg']

# %%
os.listdir(data_dir)
# Out:
# ['angry', 'happy']

# %%
os.path.join(data_dir, image_class, image)
# Out:
# 'data\\happy\\_happy_jumping_on_beach-40815.jpg'

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts:
                print('image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}' .format(image_path))
# Out:
# Issue with image data\angry\0144307B097D44218A1EF36BB9B0E5E8-1024x575.jpeg
# Issue with image data\angry\116999ecb25ac04c42cdac0a91c578439f-29-angry-face.rsocial.w1200.jpeg
# Issue with image data\angry\1409997457433_wps_12_Gerard_Butler_TELEVISION_.jpeg
# Issue with image data\angry\17377054-close-up-image-of-man-gesturing-an-angry-face-against-white-background.jpeg
# Issue with image data\angry\279095228827d80d9e1c88c79e21ea05.jpeg
# Issue with image data\angry\360_anger.jpeg
# Issue with image data\angry\360_F_218731746_Ma4YW19goP0k7rQ8Pgi7HFu74AQZt0L5.jpeg
# Issue with image data\angry\360_F_36652065_Z2UpmxgbB8GtYW3PpxerHJQKoPNR0agP.jpeg
# Issue with image data\angry\360_F_88818647_lwNDd65Sud1O5Pnaspu9D5Y0PfwgUaD6.jpeg
# Issue with image data\angry\39843011-angry-face-man.jpeg
# Issue with image data\angry\a19190a7dfcd00d59d65af8172386722f2e9ddc1.jpeg
# Issue with image data\angry\angry face.jpeg
# Issue with image data\angry\angry-eyebrows-1200x900.jpeg
# Issue with image data\angry\angry-face.jpeg
# Issue with image data\angry\angry-face_650_082914120851.jpeg
# Issue with image data\angry\angry-main.jpeg
# Issue with image data\angry\angry-man-260nw-172757603.jpeg
# Issue with image data\angry\angry-man-274175__340.jpeg
# Issue with image data\angry\angry-man-with-sneer-on-his-face-D1102E (1).jpeg
# Issue with image data\angry\angry-man-with-sneer-on-his-face-D1102E (2).jpeg
# Issue with image data\angry\angry-man-with-sneer-on-his-face-D1102E (3).jpeg
# Issue with image data\angry\angry-woman-eyes.jpeg
# Issue with image data\angry\angry_face.jpeg
# Issue with image data\angry\depositphotos_71595793-stock-photo-woman-with-angry-face.jpeg
# Issue with image data\angry\DMUbjq2UjJcG3umGv3Qjjd.jpeg
# Issue with image data\angry\emoji-face-angry-funny-character-free-vector.jpeg
# Issue with image data\angry\fa599271828f51a86a4ac0cbab63bd65.jpeg
# Issue with image data\angry\face-of-young-angry-african-man-shouting-PXP2P3.jpeg
# Issue with image data\angry\GettyImages-108328246-1024x683.jpeg
# Issue with image data\angry\GettyImages-172586047-1024x683.jpeg
# Issue with image data\angry\handsome-toddler-child-green-eyes-260nw-1098003500.jpeg
# Issue with image data\angry\head-shot-angry-face-man-asian-103009467.jpeg
# Issue with image data\happy\happy-person-banner-1.jpeg
# Issue with image data\happy\happy-person-nature-raised-arms-young-147569464.jpeg
# Issue with image data\happy\happy-person.jpeg
# Issue with image data\happy\happy-woman-in-nature-at-sunset.jpeg
# Issue with image data\happy\happy-woman.jpeg
# Issue with image data\happy\happy.jpeg
# Issue with image data\happy\Happy_guy.jpeg
# Issue with image data\happy\hdptcar-fi-2.jpeg
# Issue with image data\happy\how-to-be-happy.jpeg
# Issue with image data\happy\how-to-become-a-happy-person.jpeg
# Issue with image data\happy\images (1).jpeg
# Issue with image data\happy\images (25).jpeg
# Issue with image data\happy\images (26).jpeg
# Issue with image data\happy\images (3).jpeg
# Issue with image data\happy\images (4).jpeg
# Issue with image data\happy\images (6).jpeg
# Issue with image data\happy\images (9).jpeg
# Issue with image data\happy\intro-1494540038.jpeg
# Issue with image data\happy\joking-man.jpeg
# Issue with image data\happy\make-someone-happy.jpeg
# Issue with image data\happy\medium_Happy_Old_People_aef463ffff.jpeg
# Issue with image data\happy\nm-how-happiness-affects-health-tnail.jpeg
# Issue with image data\happy\pexels-photo-1498332.jpeg
# Issue with image data\happy\pexels-photo-1999504.jpeg
# Issue with image data\happy\pexels-photo-2923156.jpeg
# Issue with image data\happy\Photo-happy-1-unsplash-michael-dam.jpeg
# Issue with image data\happy\physed-happiness-videoSixteenByNineJumbo1600.jpeg
# Issue with image data\happy\sky-2667455_1280.jpeg
# Issue with image data\happy\Smilingman.jpeg
# Issue with image data\happy\v4-460px-Make-a-Person-Happy-Step-14.jpeg
# Issue with image data\happy\v4-460px-Make-a-Person-Happy-Step-15.jpg.jpeg
# Issue with image data\happy\v4-460px-Make-a-Person-Happy-Step-3-Version-4.jpeg
# Issue with image data\happy\what-is-a-happy-person.jpeg
# Issue with image data\happy\wp9243955.jpeg
# Issue with image data\happy\_happy_jumping_on_beach-40815.jpeg

# %%
#Load Data

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 114 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
#Images represented as nympy arrays
batch = data_iterator.next()

# %%
#class 1 = happy people, class 0= angry people
fig, ax = plt.subplots(ncols = 4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
#Preprocessing data

# %%
#scale data
data = data.map(lambda x, y: (x/255, y))

# %%
scaled_iterator = data.as_numpy_iterator()

# %%
batch = scaled_iterator.next()
batch[0].max()
# Out:
# 1.0

# %%
fig, ax = plt.subplots(ncols = 4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %%
#Split data

# %%
len(data)
# Out:
# 4

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
#Deep Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation ='relu', input_shape=(256,256,3))), 
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), 1, activation= 'relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), 1, activation= 'relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 254, 254, 16)      448
#
#  max_pooling2d_12 (MaxPoolin  (None, 127, 127, 16)     0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 125, 125, 32)      4640
#
#  max_pooling2d_13 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 60, 60, 16)        4624
#
#  max_pooling2d_14 (MaxPoolin  (None, 30, 30, 16)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 14400)             0
#
#  dense_7 (Dense)             (None, 256)               3686656
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train Model

# %%
logdir= 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2/2 [==============================] - 4s 2s/step - loss: 1.1434 - accuracy: 0.5625 - val_loss: 0.7045 - val_accuracy: 0.6875
# Epoch 2/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.8389 - accuracy: 0.5469 - val_loss: 0.7098 - val_accuracy: 0.5000
# Epoch 3/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.7613 - accuracy: 0.3438 - val_loss: 0.6758 - val_accuracy: 0.5625
# Epoch 4/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.6385 - accuracy: 0.6875 - val_loss: 0.5742 - val_accuracy: 0.6875
# Epoch 5/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.6289 - accuracy: 0.6562 - val_loss: 0.4953 - val_accuracy: 0.7500
# Epoch 6/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.6501 - accuracy: 0.6094 - val_loss: 0.5690 - val_accuracy: 0.6875
# Epoch 7/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.5489 - accuracy: 0.7031 - val_loss: 0.5679 - val_accuracy: 0.7500
# Epoch 8/20
# 2/2 [==============================] - 3s 2s/step - loss: 0.5883 - accuracy: 0.6719 - val_loss: 0.4599 - val_accuracy: 0.7812
# Epoch 9/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.5737 - accuracy: 0.6875 - val_loss: 0.4965 - val_accuracy: 0.8125
# Epoch 10/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.5599 - accuracy: 0.7656 - val_loss: 0.4985 - val_accuracy: 0.6875
# Epoch 11/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.4596 - accuracy: 0.7031 - val_loss: 0.3918 - val_accuracy: 0.7500
# Epoch 12/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.3597 - accuracy: 0.8438 - val_loss: 0.3978 - val_accuracy: 0.8125
# Epoch 13/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.3926 - accuracy: 0.8438 - val_loss: 0.3198 - val_accuracy: 0.9062
# Epoch 14/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.2469 - accuracy: 0.9375 - val_loss: 0.7134 - val_accuracy: 0.6562
# Epoch 15/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.3482 - accuracy: 0.7969 - val_loss: 0.2888 - val_accuracy: 0.9375
# Epoch 16/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.3401 - accuracy: 0.8750 - val_loss: 0.2425 - val_accuracy: 0.9062
# Epoch 17/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.2317 - accuracy: 0.9375 - val_loss: 0.3565 - val_accuracy: 0.7500
# Epoch 18/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.3366 - accuracy: 0.7812 - val_loss: 0.1988 - val_accuracy: 0.9688
# Epoch 19/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.2541 - accuracy: 0.9219 - val_loss: 0.2084 - val_accuracy: 0.9688
# Epoch 20/20
# 2/2 [==============================] - 3s 1s/step - loss: 0.2783 - accuracy: 0.9219 - val_loss: 0.1643 - val_accuracy: 0.9375

# %%
#Plot performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
#Evaluate Performance

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
prec = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    x, y = batch
    yhat = model.predict(x)
    prec.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 146ms/step

# %%
print(f'Precision :{prec.result().numpy()}, Recall: {re.result().numpy()}, Accuracy:{acc.result().numpy()}')
# Out:
# Precision :1.0, Recall: 0.9285714030265808, Accuracy:0.9444444179534912

# %%
#Test

# %%
img_test = cv2.imread('happy_test.jpeg')
plt.imshow(cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img_test, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
np.expand_dims(resize, 0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
yhat
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[0.95396316]], dtype=float32)

# %%
if yhat > 0.5:
    print(f'predicted Class is Happy')
else:
    print(f'Predicted Class is Angry')
# Out:
# predicted Class is Happy

# %%
#Saving the Model

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models', 'happyangrymodel.h5'))

# %%
#Reloading Model

# %%
new_model = load_model(os.path.join('models', 'happyangrymodel.h5'))

# %%
new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 106ms/step
# array([[0.95396316]], dtype=float32)
